# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

URL = 'https://www.cdc.gov/coronavirus/2019-ncov/locations-confirmed-cases.html'

data = requests.get(URL)
soup = BeautifulSoup(data.text)

div = soup.find('div', {'class':'col-md-4'})

# %%
df = pd.DataFrame([i.text for i in div.findAll('li')], columns = ['Country'])

# %%
df
# Out:
#                          Country
# 0                        Algeria
# 1                   Burkina Faso
# 2                       Cameroon
# 3   Democratic Republic of Congo
# 4                        Nigeria
# 5                        Senegal
# 6                   South Africa
# 7                           Togo
# 8                      Argentina
# 9                        Bolivia
# 10                        Brazil
# 11                        Canada
# 12                         Chile
# 13                      Colombia
# 14                    Costa Rica
# 15            Dominican Republic
# 16                       Ecuador
# 17                 French Guiana
# 18                     Guadalupe
# 19                      Honduras
# 20                       Jamaica
# 21                    Martinique
# 22                        Mexico
# 23                        Panama
# 24                      Paraguay
# 25                          Peru
# 26                 United States
# 27                   Afghanistan
# 28                       Bahrain
# 29                         Egypt
# 30                          Iran
# 31                          Iraq
# 32                        Jordan
# 33                        Kuwait
# 34                       Lebanon
# 35                       Morocco
# 36                          Oman
# 37                      Pakistan
# 38                         Qatar
# 39                  Saudi Arabia
# 40                       Tunisia
# 41          United Arab Emirates

# %%
import plotly.graph_objects as go

fig = go.Figure(data=go.Choropleth(
    locations = df['Country'],
    text = df['Country'],
    colorscale = 'Blues',
    autocolorscale=False,
    reversescale=True,
    marker_line_color='darkgray',
    marker_line_width=0.5
))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-86-12ec4a408bd3> in <module>
#       2
#       3 fig = go.Figure(data=go.Choropleth(
# ----> 4     locations = df['Country']
#       5 ))
#
# c:\users\kalya\appdata\local\programs\python\python37\lib\site-packages\plotly\graph_objs\_choropleth.py in __init__(self, arg, autocolorscale, colorbar, colorscale, customdata, customdatasrc, geo, hoverinfo, hoverinfosrc, hoverlabel, hovertemplate, hovertemplatesrc, hovertext, hovertextsrc, ids, idssrc, legendgroup, locationmode, locations, locationssrc, marker, name, opacity, reversescale, selected, selectedpoints, showlegend, showscale, stream, text, textsrc, uid, uirevision, unselected, visible, z, zauto, zmax, zmid, zmin, zsrc, **kwargs)
#
# AttributeError: module 'plotly.validators.choropleth' has no attribute 'OpacityValidator'
